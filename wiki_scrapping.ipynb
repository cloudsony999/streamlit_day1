# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in e:\visualdata\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\visualdata\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\visualdata\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\visualdata\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in e:\visualdata\lib\site-packages (from requests) (2024.2.2)

# %%
page="https://en.wikipedia.org/wiki/Economic_development_in_India"

# %%
html=requests.get(page,timeout=5,verify=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 html=requests.get(page,timeout=5,verify=True)
#
# NameError: name 'requests' is not defined

# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.31.0
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache 2.0
# Location: E:\visualdata\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: jupyterlab_server

# %%
requests.get(page,timeout=5,verify=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 requests.get(page,timeout=5,verify=True)
#
# NameError: name 'requests' is not defined

# %%
import requests

# %%
html=requests.get(page,timeout=5,verify=True)

# %%
html.text[:1000]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-clientpref-0 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Economic development in India - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned'

# %%
html
# Out:
# <Response [200]>

# %%
html.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-clientpref-0 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Economic development in India - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-clientpref-0 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],\n"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"d23b3e73-162c-4040-90a4-0c4db6957958","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Economic_development_in_India","wgTitle":"Economic development in India","wgCurRevisionId":1220618732,"wgRevisionId":1220618732,"wgArticleId":13770627,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Webarchive template wayback links","CS1 maint: archived copy as title","CS1 errors: missing periodical","CS1 maint: unfit URL","CS1 maint: multiple names: authors list","Articles with short description","Short description is different from Wikidata","Use dmy dates from May 2014","Use Indian English from June 2016","All Wikipedia articles written in Indian English",\n"Wikipedia articles in need of updating from July 2021","All Wikipedia articles in need of updating","Wikipedia introduction cleanup from July 2021","All pages needing cleanup","Articles covered by WikiProject Wikify from July 2021","All articles covered by WikiProject Wikify","Articles with multiple maintenance issues","All articles with unsourced statements","Articles with unsourced statements from January 2024","Articles with unsourced statements from January 2023","Articles with unsourced statements from December 2008","All pages needing factual verification","Wikipedia articles needing factual verification from January 2023","Wikipedia external links cleanup from January 2023","Economic development in India","Economy of India","Development in Asia"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Economic_development_in_India","wgRelevantArticleId":13770627,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":\ntrue,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariant ...

# %%
html.text[:1000]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-clientpref-0 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Economic development in India - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned'

# %%
#LOAD HTML IN PANDAS DATAFRAME

# %%
import pandas as pd

# %%
dfs=pd.read_html(html.text)
dfs
# Out:
# C:\Users\91759\AppData\Local\Temp\ipykernel_5436\3443659843.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs=pd.read_html(html.text)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File E:\visualdata\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File C:\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'lxml'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dfs=pd.read_html(html.text)
#       2 dfs
#
# File E:\visualdata\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
#    1244     header=header,
#    1245     index_col=index_col,
#    1246     skiprows=skiprows,
#    1247     parse_dates=parse_dates,
#    1248     thousands=thousands,
#    1249     attrs=attrs,
#    1250     encoding=encoding,
#    1251     decimal=decimal,
#    1252     converters=converters,
#    1253     na_values=na_values,
#    1254     keep_default_na=keep_default_na,
#    1255     displayed_only=displayed_only,
#    1256     extract_links=extract_links,
#    1257     dtype_backend=dtype_backend,
#    1258     storage_options=storage_options,
#    1259 )
#
# File E:\visualdata\Lib\site-packages\pandas\io\html.py:971, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     969 retained = None
#     970 for flav in flavor:
# --> 971     parser = _parser_dispatch(flav)
#     972     p = parser(
#     973         io,
#     974         compiled_match,
#    (...)
#     979         storage_options,
#     980     )
#     982     try:
#
# File E:\visualdata\Lib\site-packages\pandas\io\html.py:918, in _parser_dispatch(flavor)
#     916     import_optional_dependency("bs4")
#     917 else:
# --> 918     import_optional_dependency("lxml.etree")
#     919 return _valid_parsers[flavor]
#
# File E:\visualdata\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'lxml'.  Use pip or conda to install lxml.

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-5.2.1-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Downloading lxml-5.2.1-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 682.7 kB/s eta 0:00:06
#     --------------------------------------- 0.1/3.8 MB 660.6 kB/s eta 0:00:06
#    - -------------------------------------- 0.2/3.8 MB 1.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.4/3.8 MB 2.4 MB/s eta 0:00:02
#    --------- ------------------------------ 1.0/3.8 MB 4.3 MB/s eta 0:00:01
#    -------------------- ------------------- 2.0/3.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 12.2 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-5.2.1

# %%
dfs=pd.read_html(html.text)
dfs
# Out:
# C:\Users\91759\AppData\Local\Temp\ipykernel_5436\3443659843.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs=pd.read_html(html.text)
# [    0                                                  1
#  0 NaN  This article has multiple issues. Please help ...
#  1 NaN  This article needs to be updated. Please help ...
#  2 NaN  The article's lead section may need to be rewr...
#  3 NaN  This article's lead section may be too long. P...,
#      0                                                  1
#  0 NaN  This article needs to be updated. Please help ...,
#      0                                                  1
#  0 NaN  The article's lead section may need to be rewr...,
#      0                                                  1
#  0 NaN  This article's lead section may be too long. P...,
#      Year  Growth (real) (%)
#  0   2000              3.841
#  1   2001              4.824
#  2   2002              3.804
#  3   2003              7.860
#  4   2004              7.923
#  5   2005              7.923
#  6   2006              8.061
#  7   2007              7.661
#  8   2008              3.087
#  9   2009              7.862
#  10  2010              8.498
#  11  2011              5.241
#  12  2012              5.456
#  13  2013              6.386
#  14  2014              7.410
#  15  2015              7.996
#  16  2016              8.170
#  17  2017              7.168
#  18  2018              6.982,
#     World Rank                          Company  Logo                Industry  \
#  0         142              Reliance Industries   NaN    Oil & Gas Operations
#  1         152              State Bank of India   NaN                 Banking
#  2         183  Oil and Natural Gas Corporation   NaN    Oil & Gas Operations
#  3         263                      Tata Motors   NaN                     NaN
#  4         283                       ICICI Bank   NaN                 Banking
#  5         431                             NTPC   NaN               Utilities
#  6         463                       Tata Steel   NaN               Materials
#  7         349           Indian Oil Corporation   NaN    Oil & Gas Operations
#  8         485                             HDFC   NaN                 Banking
#  9         485                              TCS   NaN  Information Technology
#
#     Revenue (billion $)  Profits (billion $)  Assets (billion $)  \
#  0                71.70                 3.70               76.60
#  1                40.80                 2.30              400.60
#  2                28.70                 4.40               59.30
#  3                42.30                 2.70               34.70
#  4                14.20                 1.90              124.80
#  5                12.90                 1.90               35.40
#  6                32.77                 3.08               31.16
#  7                74.30                 1.20               44.70
#  8                 8.40                 1.40               84.30
#  9                15.10                 3.50               11.00
#
#     Market Value (billion $)
#  0                     42.90
#  1                     33.00
#  2                     43.70
#  3                     28.80
#  4                     30.00
#  5                     20.20
#  6                      2.46
#  7                     14.60
#  8                     41.60
#  9                     80.30  ,
#      0                                                  1
#  0 NaN  This section's use of external links may not f...,
#               vte Economy of India  \
#  0                       Companies
#  1                      Governance
#  2                        Currency
#  3              Financial services
#  4                         History
#  5                          People
#  6                        By state
#  7                         Sectors
#  8                       Regulator
#  9                           Other
#  10  Category  Commons  Wikiquotes
#
#                                 vte Economy of India.1
#  0                                 BSE SENSEX NIFTY 50
#  1   Ministry of Finance Finance ministers Ministry...
#  2   Indian rupee Sign History Historical Forex Dig...
#  3   Banking Insurance Multi Commodity Exchange Bul...
#  4   COVID-19 impact Economic development Liberalis...
#  5   Billionaires Demography Income Poverty Labour ...
#  6   Andhra Pradesh Assam Bihar Delhi Goa Gujarat H...
#  7   Agriculture Livestock Fishing Automotive Chemi...
#  8                                 IRDAI RBI SEBI IBBI
#  9   NCLT NCLAT BIFR IBBI IBC SARFESI Act Income Ta...
#  10                      Category  Commons  Wikiquotes  ]

# %%
len(dfs)
# Out:
# 8

# %%
dfs[4].head()
# Out:
#    Year  Growth (real) (%)
# 0  2000              3.841
# 1  2001              4.824
# 2  2002              3.804
# 3  2003              7.860
# 4  2004              7.923

# %%
dfs[4].tail()
# Out:
#     Year  Growth (real) (%)
# 14  2014              7.410
# 15  2015              7.996
# 16  2016              8.170
# 17  2017              7.168
# 18  2018              6.982

# %%
df=dfs[4]
df.head()
# Out:
#    Year  Growth (real) (%)
# 0  2000              3.841
# 1  2001              4.824
# 2  2002              3.804
# 3  2003              7.860
# 4  2004              7.923

# %%
df.shape
# Out:
# (19, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               19 non-null     int64
#  1   Growth (real) (%)  19 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 436.0 bytes

# %%
df.columns
# Out:
# Index(['Year', 'Growth (real) (%)'], dtype='object')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.plot(df['Year'], df['Growth (real) (%)'])
plt.title('GDP Growth Rate in %', color = "red", fontsize = 20)
plt.xlabel("Year")
plt.ylabel("Growth (real) (%)")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(df['Year'], df['Growth (real) (%)'])
plt.title('GDP Growth Rate in %', color = "red", fontsize = 20)
plt.xlabel("Year")
plt.ylabel("Growth (real) (%)")
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.pie(df['Growth (real) (%)'], labels = df['Year'], autopct='%1.1f%%')
plt.title('GDP Growth Rate in %', color = "red", fontsize = 20)
plt.legend(loc ="center right", fontsize = 10)
plt.show()

# %%
dfs[5].head()
# Out:
#    World Rank                          Company  Logo              Industry  \
# 0         142              Reliance Industries   NaN  Oil & Gas Operations
# 1         152              State Bank of India   NaN               Banking
# 2         183  Oil and Natural Gas Corporation   NaN  Oil & Gas Operations
# 3         263                      Tata Motors   NaN                   NaN
# 4         283                       ICICI Bank   NaN               Banking
#
#    Revenue (billion $)  Profits (billion $)  Assets (billion $)  \
# 0                 71.7                  3.7                76.6
# 1                 40.8                  2.3               400.6
# 2                 28.7                  4.4                59.3
# 3                 42.3                  2.7                34.7
# 4                 14.2                  1.9               124.8
#
#    Market Value (billion $)
# 0                      42.9
# 1                      33.0
# 2                      43.7
# 3                      28.8
# 4                      30.0

# %%
df1 = dfs[5]
df1.head(10)
# Out:
#    World Rank                          Company  Logo                Industry  \
# 0         142              Reliance Industries   NaN    Oil & Gas Operations
# 1         152              State Bank of India   NaN                 Banking
# 2         183  Oil and Natural Gas Corporation   NaN    Oil & Gas Operations
# 3         263                      Tata Motors   NaN                     NaN
# 4         283                       ICICI Bank   NaN                 Banking
# 5         431                             NTPC   NaN               Utilities
# 6         463                       Tata Steel   NaN               Materials
# 7         349           Indian Oil Corporation   NaN    Oil & Gas Operations
# 8         485                             HDFC   NaN                 Banking
# 9         485                              TCS   NaN  Information Technology
#
#    Revenue (billion $)  Profits (billion $)  Assets (billion $)  \
# 0                71.70                 3.70               76.60
# 1                40.80                 2.30              400.60
# 2                28.70                 4.40               59.30
# 3                42.30                 2.70               34.70
# 4                14.20                 1.90              124.80
# 5                12.90                 1.90               35.40
# 6                32.77                 3.08               31.16
# 7                74.30                 1.20               44.70
# 8                 8.40                 1.40               84.30
# 9                15.10                 3.50               11.00
#
#    Market Value (billion $)
# 0                     42.90
# 1                     33.00
# 2                     43.70
# 3                     28.80
# 4                     30.00
# 5                     20.20
# 6                      2.46
# 7                     14.60
# 8                     41.60
# 9                     80.30

# %%
df1.shape
# Out:
# (10, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   World Rank                10 non-null     int64
#  1   Company                   10 non-null     object
#  2   Logo                      0 non-null      float64
#  3   Industry                  9 non-null      object
#  4   Revenue (billion $)       10 non-null     float64
#  5   Profits (billion $)       10 non-null     float64
#  6   Assets (billion $)        10 non-null     float64
#  7   Market Value (billion $)  10 non-null     float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 772.0+ bytes

# %%
plt.figure(figsize=(12,8))
plt.bar(df1['Company'], df1['Assets (billion $)'])
plt.title('10 Leading Companies by Assets', fontsize = 20)
plt.xlabel("Companies", fontsize = 20)
plt.ylabel("Assets in billion '$'", fontsize = 20)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.pie(df1['Assets (billion $)'], labels = df1['Company'], autopct='%1.1f%%')
plt.legend(title = "Companies", loc ="upper right")
plt.title('10 Leading Companies by Assets', fontsize = 22)
plt.show()
